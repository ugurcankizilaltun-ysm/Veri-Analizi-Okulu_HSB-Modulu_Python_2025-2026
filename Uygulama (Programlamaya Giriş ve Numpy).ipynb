# %% [markdown]
# # Python Uygulama Egzersizleri
#
# Bu çalışma kağıdı, derste gördüğümüz konuları **bol pratikle** pekiştirmek için hazırlandı.
# Her soru bir “mini görev” gibi düşünülebilir.
#
# ## Genel yönergeler
# - Her soruyu **ayrı bir başlık** altında çözün.
# - Kodun içine kısa kısa açıklamalar yazın (`# burada şunu yapıyorum`).
# - Aynı işi tekrar yapıyorsanız, mümkünse **fonksiyon** yazın.
# - Her sorunun sonunda **kendi küçük testinizi** yapın (örnek bir çıktı alın, birkaç değer yazdırın).
#
# > İpucu: Hata alırsanız paniğe gerek yok. Hata mesajında genellikle **hangi satırda** sorun olduğu yazar.

# %% [markdown]
# ## 1) Formatlı çıktı: “Profil Kartı”
#
# **Bu soruda amaç:** Kullanıcıdan bilgi almak ve ekrana düzgün bir şekilde yazdırmak.
#
# **Görev:**
# 1. Kullanıcıdan sırayla şunları alın: **ad**, **soyad**, **yaş**, **şehir**
# 2. Ekrana üç satırlık bir “profil kartı” yazdırın:
#    - `Ad Soyad: ...`
#    - `Yaş: ...`
#    - `Şehir: ...`
#
# **Ek koşullar:**
# - En az bir satırda **f-string** kullanın (ör. `f"Merhaba {ad}"`).
# - En az bir `print()` içinde `sep=` veya `end=` kullanın.

# %%
# Çözümünüz (Soru 1)

# 1) Girdileri alınız
# 2) Formatlı biçimde yazdırınız

# %% [markdown]
# ## 2) Liste uygulaması: Harcama Özeti
#
# **Bu soruda amaç:** Bir liste üzerinde dolaşmak, toplamak ve basit koşul yazmak.
#
# **Veri:**
# Aşağıdaki harcamaları liste olarak tanımlayın:
# ```python
# harcamalar = [120, 45, 230, 15, 80, 60]
# ```
#
# **Görev:**
# 1. Toplam harcamayı bulun.
# 2. En büyük ve en küçük harcamayı bulun.
# 3. 100 TL üzerindeki harcama sayısını bulun.
# 4. Eğer toplam harcama **500’ü geçiyorsa**, toplam üzerinden **%10 indirim** uygulayın ve “indirimli toplamı” yazdırın.
#
# **Kural:**
# - Toplamı `sum()` ile değil, **`for` döngüsü** ile hesaplayın.

# %%
# Çözümünüz (Soru 2)

harcamalar = [120, 45, 230, 15, 80, 60]

# 1) Toplam (for ile)
# 2) min / max
# 3) 100 üstü sayısı
# 4) Koşullu indirim

# %% [markdown]
# ## 3) Liste + sözlük: Mini “Film Arşivi”
#
# **Bu soruda amaç:** Liste içinde sözlüklerle çalışmak (arama, güncelleme, ekleme).
#
# **Veri:**
# Aşağıdaki veri yapısını oluşturun:
# ```python
# filmler = [
#     {"ad": "Spirited Away", "yil": 2001, "puan": 8.6},
#     {"ad": "Inception", "yil": 2010, "puan": 8.8},
#     {"ad": "Parasite", "yil": 2019, "puan": 8.5},
# ]
# ```
#
# **Görev 1 — Arama:**
# - Kullanıcıdan bir film adı alın.
# - Arşivde varsa filmin puanını yazdırın.
# - Yoksa `Film bulunamadı.` yazdırın.
#
# **Görev 2 — Güncelleme:**
# - Kullanıcıdan bir film adı alın.
# - Arşivde varsa puanını **0.1 artırın** (ör. 8.5 → 8.6).
#
# **Görev 3 — Fonksiyonla ekleme:**
# - Şu fonksiyonu yazın: `film_ekle(liste, ad, yil, puan)`
# - Bu fonksiyon yeni filmi listeye eklesin.
#
# **Görev 4 — Filtreleme:**
# - **2010 ve sonrası** filmleri seçip yeni bir listeye koyun.
#
# **Not:**
# - Arama/güncelleme için `for` + `if` kullanmanız bekleniyor.

# %%
# Çözümünüz (Soru 3)

filmler = [
    {"ad": "Spirited Away", "yil": 2001, "puan": 8.6},
    {"ad": "Inception", "yil": 2010, "puan": 8.8},
    {"ad": "Parasite", "yil": 2019, "puan": 8.5},
]

# 1) Arama
# 2) Puan güncelleme (+0.1)
# 3) film_ekle fonksiyonu
# 4) 2010+ filtreleme

# %% [markdown]
# ## 4) Girdi kontrolü: Not Dönüştürücü
#
# **Bu soruda amaç:** Kullanıcının yanlış giriş yapmasına karşı programı “sağlam” tutmak.
#
# **Görev:**
# Kullanıcıdan **0–100** arası bir not isteyin.
# - Not geçerli değilse (ör. -5, 120, boş, “abc” gibi), tekrar sorun.
# - Geçerli notu aşağıdaki tabloya göre harf notuna çevirin:
#
# | Aralık | Harf |
# |---|---|
# | 90–100 | AA |
# | 80–89  | BA |
# | 70–79  | BB |
# | 60–69  | CB |
# | 50–59  | CC |
# | 0–49   | FF |
#
# **İpucu (opsiyonel ama çok faydalı):**
# - Kullanıcı sayı yerine yazı girerse program hata verebilir.
# - Bunu engellemek için `try/except` kullanabilirsiniz.

# %%
# Çözümünüz (Soru 4)

# 1) while ile girdi doğrulama
# 2) try/except ile sayısal olmayan girişleri yönetme
# 3) if/elif ile harf notu belirleme

# %% [markdown]
# ## 5) NumPy: 2 Boyutlu Noktalar ve “Yakın/Uzak” Seçme
#
# **Bu soruda amaç:** NumPy ile çok sayıda veriyi tek seferde işlemek (vektörleştirme) ve “maske” (seçme) yapmak.
#
# ### Terimler (kısa açıklama)
# - **2 boyutlu nokta**: Bir nokta `(x, y)` ile gösterilir.
# - **Orijin**: Koordinat sisteminin başlangıcı, yani `(0, 0)`.
# - **Mesafe**: Bir noktanın orijine “ne kadar uzak” olduğunu sayı olarak düşünün.
#   Basit formül:
#
#   `mesafe = sqrt(x^2 + y^2)`
#   Burada `sqrt` karekök demektir (NumPy’da `np.sqrt`).
#
# ### Görev
# 1. `numpy` ile `N=200` adet 2 boyutlu nokta üretin:
#    - Her noktanın `x` ve `y` değeri `[-5, 5]` aralığında rastgele olsun.
#    - Sonuç dizisinin şekli `(200, 2)` olsun.
# 2. Her noktanın orijine olan mesafesini hesaplayın:
#    - Mesafeler `(200,)` şekilli tek boyutlu bir dizi olsun.
# 3. Mesafesi `r = 3` **ve daha küçük** olan noktaları seçin (boolean maske ile).
# 4. Seçilenler için:
#    - Kaç nokta seçildi?
#    - Seçilenlerin ortalama mesafesi nedir?
#    - Seçilmeyenlerin ortalama mesafesi nedir?
#    yazdırın.
#
# ### Kural
# - Mesafe hesabını mümkünse **for döngüsü olmadan**, NumPy ile topluca yapın.
# - `axis` parametresini doğru kullanmaya dikkat edin.

# %%
# Çözümünüz (Soru 5)

import numpy as np

# 1) Noktaları üretiniz (200, 2)
# 2) Mesafeleri hesaplayınız (200,)
# 3) r=3 için maske oluşturunuz
# 4) İstenen özetleri yazdırınız

# %% [markdown]
# ## 6) Matplotlib: Noktaları Çiz ve Dağılıma Bak
#
# **Bu soruda amaç:** Basit grafikler çizmek (scatter ve histogram) ve grafikleri okunur hale getirmek.
#
# Bu soruda **5. soruda ürettiğiniz**:
# - noktaları (points),
# - mesafeleri (distances),
# - maskeyi (mask)
# kullanın.
#
# ### A) Saçılım (scatter) grafiği
# 1. Tüm noktaları `plt.scatter` ile çizin.
# 2. `r = 3` içinde kalan noktaları ayrıca çizerek **vurgulayın** (yani ikinci bir `scatter`).
# 3. Orijini `(0, 0)` noktasını da ayrı bir işaretle gösterin.
# 4. Başlık, x/y etiketleri ve legend ekleyin.
#
# ### B) Histogram
# 1. Mesafelerin histogramını çizin (`plt.hist`).
# 2. `bins` için 20–30 gibi bir değer seçebilirsiniz.
# 3. Başlık ve eksen etiketlerini ekleyin.
#
# ### Kural
# - En az bir grafikte `plt.figure(...)` ile boyut ayarlayın.
# - En sonda `plt.show()` ile grafikleri gösterin.

# %%
# Çözümünüz (Soru 6)

import matplotlib.pyplot as plt

# Not: 5. sorudaki noktaları (points), mesafeleri (distances) ve maskeyi (mask) burada kullanınız.

# A) Saçılım grafiği
# B) Histogram
# plt.show()

# %% [markdown]
# ### Bir Not
# - Her sorunun sonunda küçük bir kontrol çıktısı alın (ör. toplam harcama, seçilen nokta sayısı vb.).
# - Kodun okunabilirliği (değişken isimleri, yorumlar, hücre düzeni) önemlidir.
#
# *Güncelleme tarihi:* 2026-01-01 19:44
